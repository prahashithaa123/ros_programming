# %% [markdown]
# # Simple MNIST convnet
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/19<br>
# **Last modified:** 2020/04/21<br>
# **Description:** A simple convnet that achieves ~99% test accuracy on MNIST.

# %% [markdown]
# ## Setup

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# Use cv2.imshow in colab

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Prepare the data

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
import datetime
print("Training the Model ....")
start_time=datetime.datetime.now()
print("Training started at: {}".format(start_time))
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
end_time= datetime.datetime.now()
print("Training ended at: {}".format(end_time))
duration = end_time - start_time
print("Training Duration: {}".format(duration))
# Out:
# Training the Model ....
# Training started at: 2023-03-17 03:39:45.976006
# Epoch 1/15
# 422/422 [==============================] - 14s 7ms/step - loss: 0.3834 - accuracy: 0.8813 - val_loss: 0.0793 - val_accuracy: 0.9792
# Epoch 2/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1122 - accuracy: 0.9655 - val_loss: 0.0595 - val_accuracy: 0.9850
# Epoch 3/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0837 - accuracy: 0.9743 - val_loss: 0.0485 - val_accuracy: 0.9877
# Epoch 4/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0712 - accuracy: 0.9780 - val_loss: 0.0404 - val_accuracy: 0.9895
# Epoch 5/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0590 - accuracy: 0.9820 - val_loss: 0.0368 - val_accuracy: 0.9905
# Epoch 6/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0546 - accuracy: 0.9828 - val_loss: 0.0368 - val_accuracy: 0.9900
# Epoch 7/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0504 - accuracy: 0.9838 - val_loss: 0.0361 - val_accuracy: 0.9905
# Epoch 8/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0464 - accuracy: 0.9853 - val_loss: 0.0351 - val_accuracy: 0.9913
# Epoch 9/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0435 - accuracy: 0.9866 - val_loss: 0.0328 - val_accuracy: 0.9912
# Epoch 10/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0407 - accuracy: 0.9874 - val_loss: 0.0341 - val_accuracy: 0.9905
# Epoch 11/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0384 - accuracy: 0.9875 - val_loss: 0.0297 - val_accuracy: 0.9928
# Epoch 12/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0373 - accuracy: 0.9887 - val_loss: 0.0310 - val_accuracy: 0.9917
# Epoch 13/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.0290 - val_accuracy: 0.9915
# Epoch 14/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0291 - val_accuracy: 0.9925
# Epoch 15/15
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.0303 - val_accuracy: 0.9917
# Training ended at: 2023-03-17 03:40:28.467902
# Training Duration: 0:00:42.491896

# %% [markdown]
# ## Evaluate the trained model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.025085028260946274
# Test accuracy: 0.9916999936103821
